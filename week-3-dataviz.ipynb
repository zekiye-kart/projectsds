# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.6 kB 262.6 kB/s eta 0:00:02
#    -------- ------------------------------ 61.4/294.6 kB 328.2 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/294.6 kB 504.4 kB/s eta 0:00:01
#    ------------------------- ------------ 194.6/294.6 kB 737.3 kB/s eta 0:00:01
#    ----------------------------------- -- 276.5/294.6 kB 896.4 kB/s eta 0:00:01
#    ------------------------------------ - 286.7/294.6 kB 886.2 kB/s eta 0:00:01
#    -------------------------------------- 294.6/294.6 kB 758.2 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
import seaborn as sns
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Group' : ['A' , 'B', 'C' , 'D', 'E'],
    'Value' : [1,5,4,3,9]
})

# %%
plt.barh(y=df.Group, width=df.Value)
#barh fonksiyonu, yatay (horizontal) çubukları çizmek için kullanılır. 
# y=df.Group ifadesi, çubukların yatay konumlarını belirtir,  yani hangi kategoride olduklarını gösterir.
# width=df.Value ifadesi, çubukların uzunluklarını belirtir, yani her bir kategori için belirtilen 'Value' değerine göre uzunlukları ifade eder.
# Out:
# <BarContainer object of 5 artists>

# %%
df = df.sort_values(by = ['Value'])
plt.barh(
    y=df.Group, 
    width=df.Value, 
    color= mcolors.TABLEAU_COLORS ,
    edgecolor= 'black',
    linewidth = 3
    )
#plt.bar_label(Container = mybarplot)
# Out:
# <BarContainer object of 5 artists>

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.set(style= "darkgrid")
sns.barplot(
    x= "total_bill",
    y= "day",
    data = tips,
    color = "cyan"
)
plt.figure(figsize=(18,8))

# %%
g = sns.FacetGrid(tips, col="day", height=4, aspect=.5)
g.map(sns.barplot, "sex", "total_bill", order=["Male", "Female"])

# %%
sns.barplot(
        x="total_bill",
        y="smoker",
        hue="sex",
        data=tips,
        color="pink"
        )
plt.figure(figsize=(16, 8))
# Out:
# C:\Users\Zekiye\AppData\Local\Temp\ipykernel_6884\1953333789.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.barplot(

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
total = tips.groupby("day")["total_bill"].sum().reset_index()
# Out:
# C:\Users\Zekiye\AppData\Local\Temp\ipykernel_6884\64266192.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total = tips.groupby("day")["total_bill"].sum().reset_index()

# %%
total
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')

# %%
smoker = tips[tips.smoker == "Yes"]

# %%
bar2 = sns.barplot(
    x="day",
    y="total_bill",
    data = smoker,
    estimator= sum,
    errorbar = None,
    color = "lightblue"
)

# %%
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')
bar2 = sns.barplot(
    x='day',
    y='total_bill',
    data=smoker,
    estimator=sum,
    errorbar=None,
    color='lightblue'
)
top_bar = mpatches.Patch(color='darkblue', label='non-smoker')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])
plt.show()

# %%
df_iris = sns.load_dataset("iris")

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data = df_iris, x ="sepal_length", kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
#sns.displot(df_iris["sepal_length"])
#displot is deprecated

# %%
sns.regplot(
    x=df_iris["sepal_length"], 
    y=df_iris["sepal_width"],
    marker = "+",
    line_kws={
        "color" : "red",
        "alpha": 0.6,
        "lw" : 5
    },
    scatter_kws = {
        "color" : "darkblue",
        "s": 50
    }
    )
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lmplot(
    x="sepal_length", 
    y="sepal_width",
    data = df_iris,
    hue="species",
    
)

# %%
sns.set_theme(style="white", palette="pastel")
sns.boxplot(x=df_iris["species"], y=df_iris["sepal_length"])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
df_iris.boxplot(column = "sepal_length", by="species")
plt.show()
